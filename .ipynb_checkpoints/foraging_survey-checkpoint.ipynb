# %% [markdown]
# # Falling Fruit Data Cleaning Survey

# %%
import pandas as pd
df = pd.read_csv('foraging_survey.csv')
df.head
# Out:
# <bound method NDFrame.head of               Timestamp How long have you been foraging?  \
# 0    6/17/2025 12:40:38                        3-4 years
# 1    6/17/2025 12:42:08                        1-2 years
# 2    6/17/2025 12:42:10                         5+ years
# 3    6/17/2025 12:42:43                         5+ years
# 4    6/17/2025 12:46:32                        3-4 years
# ..                  ...                              ...
# 145   6/19/2025 3:03:09                               15
# 146   6/19/2025 4:41:35                         5+ years
# 147   6/19/2025 5:00:53                     Under 1 year
# 148   6/19/2025 6:58:50                         5+ years
# 149   6/19/2025 7:20:36                        3-4 years
#
#     What kinds of environments do you forage in?  \
# 0                                Urban, Suburban
# 1                                Urban, Suburban
# 2                                Suburban, Rural
# 3                   Urban, Suburban, Rural, Wild
# 4                                          Urban
# ..                                           ...
# 145                 Urban, Suburban, Rural, Wild
# 146                 Urban, Suburban, Rural, Wild
# 147                                        Urban
# 148                 Urban, Suburban, Rural, Wild
# 149                        Urban, Suburban, Wild
#
#     Have you heard of Falling Fruit?  \
# 0                                Yes
# 1                                Yes
# 2                                Yes
# 3                                Yes
# 4                                Yes
# ..                               ...
# 145                              Yes
# 146                              Yes
# 147                              Yes
# 148                              Yes
# 149                              Yes
#
#     Have you used the Falling Fruit website or app?  \
# 0                                               Yes
# 1                                               Yes
# 2                                               Yes
# 3                                               Yes
# 4                                               Yes
# ..                                              ...
# 145                                             Yes
# 146                                             Yes
# 147                                             Yes
# 148                                             Yes
# 149                                             Yes
#
#           How did you find out about Falling Fruit?  \
# 0              Word of mouth (friends, family, etc)
# 1                                            Google
# 2                                            Reddit
# 3              Word of mouth (friends, family, etc)
# 4    Google search and news articles about foraging
# ..                                              ...
# 145                                       Tinterweb
# 146            Word of mouth (friends, family, etc)
# 147            Word of mouth (friends, family, etc)
# 148            Word of mouth (friends, family, etc)
# 149                                          Reddit
#
#     How long have you been using Falling Fruit?  \
# 0                                  2 to 5 years
# 1                           6 months to 2 years
# 2                                  2 to 5 years
# 3                                      5+ years
# 4                           6 months to 2 years
# ..                                          ...
# 145           I don't use Falling Fruit anymore
# 146                                    5+ years
# 147                         6 months to 2 years
# 148                                2 to 5 years
# 149                                2 to 5 years
#
#             What do you like about the website or app?  \
# 0                                                  NaN
# 1    Occasionally being able to find some great fru...
# 2    Searchable maps with date-coded user-sourced d...
# 3           User generated content that is geolocated
# 4    I like the ease of adding new locations, map/v...
# ..                                                 ...
# 145                                    Postcode search
# 146                 Open source community data sharing
# 147                    Easy  to find listings and POIs
# 148                                  Free public input
# 149  I liked how it was easy to see marked plants a...
#
#     What do you dislike about the website or app? What features are hard to use?  \
# 0    Harder even in the beta version to filter by c...
# 1    Just wish there were more identified spots to ...
# 2                                                  NaN
# 3              Not enough UGC (user generated content)
# 4    Hard to search for non-specific species (e.g. ...
# ..                                                 ...
# 145  Location messes up when adding plants to the d...
# 146  The maps sometimes don't load properly, crash,...
# 147  The fact it's a static backend solely on the w...
# 148                                                NaN
# 149  The app was buggy but in some cases it was eas...
#
#        What would you change about the website or app?  ...  \
# 0    Filtering by variety AND (private but overhang...  ...
# 1                                                  NaN  ...
# 2                                                  NaN  ...
# 3                       Get more people to contribute!  ...
# 4    Remember by default if tree inventory is turne...  ...
# ..                                                 ...  ...
# 145  Make the app more automated for adding new plants  ...
# 146                        Clean up crashing/glitching  ...
# 147                                                NaN  ...
# 148                                            Filters  ...
# 149  Make it easier to see what plants are in the a...  ...
#
#     Are your trees directly accessible from the street or sidewalk?  \
# 0                                                  Yes
# 1                                                  NaN
# 2                                                  NaN
# 3                                                   No
# 4                                                  NaN
# ..                                                 ...
# 145                                                 No
# 146                                                 No
# 147                                                NaN
# 148                                                 No
# 149                                                NaN
#
#     Would you be open to letting people pick from your trees if there are ways to set clear boundaries?  \
# 0                                                  Yes
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  Yes
# 4                                                  NaN
# ..                                                 ...
# 145                                                Yes
# 146                                                 No
# 147                                                NaN
# 148                                                Yes
# 149                                                NaN
#
#     If you selected no, please briefly explain why.  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 145                                             NaN
# 146                    Safety issue as I live alone
# 147                                             NaN
# 148                                             NaN
# 149                                             NaN
#
#     Have you ever resorted to your own methods to encourage or discourage harvesting fruit from your trees?  \
# 0    A little sign that says 'im ready to eat when ...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 145                                                 No
# 146                                                 No
# 147                                                NaN
# 148                                                NaN
# 149                                                NaN
#
#     Have you ever had foragers pick from your tree?  \
# 0                                               Yes
# 1                                               NaN
# 2                                               NaN
# 3                                               Yes
# 4                                               NaN
# ..                                              ...
# 145                                          Unsure
# 146                                              No
# 147                                             NaN
# 148                                              No
# 149                                             NaN
#
#     If you selected yes to the previous question, how did it go?   \
# 0    Loved seeing little munchkins walk away with p...
# 1                                                  NaN
# 2                                                  NaN
# 3                                               Great!
# 4                                                  NaN
# ..                                                 ...
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
# 148                                                NaN
# 149                                                NaN
#
#     If there was a feature to share information about your fruit trees with potential harvesters, what kind of details would you want to include?  \
# 0    When the fruit is ready to harvest, Preferred ...
# 1                                                  NaN
# 2                                                  NaN
# 3    When the fruit is ready to harvest, Preferred ...
# 4                                                  NaN
# ..                                                 ...
# 145  When the fruit is ready to harvest, How much f...
# 146  Whether foragers can enter the property or not...
# 147                                                NaN
# 148  When the fruit is ready to harvest, Preferred ...
# 149                                                NaN
#
#        Age        Country  If you are located in the US, what state?
# 0    25-34  United States                                    Florida
# 1    45-54  United States                                   New York
# 2    35-44  United States                             North Carolina
# 3    25-34  United States                                California
# 4    25-34  United States                                 California
# ..     ...            ...                                        ...
# 145  45-54             Uk                                        NaN
# 146  25-34  United States                                         IL
# 147  25-34         Canada                                        NaN
# 148  35-44  United States                                   Virginia
# 149  18-24  United States                                  Virginia
#
# [150 rows x 34 columns]>

# %%
df.rename(columns={'How did you find out about Falling Fruit?': 'FindFF', 
                   'If you are located in the US, what state?': 'State'}, inplace=True)

# %%
# filtering for the questions Edlyn is cleaning
new_df = df[['FindFF', 'State']]

# %%
new_df
# Out:
#                                              FindFF           State
# 0              Word of mouth (friends, family, etc)         Florida
# 1                                            Google        New York
# 2                                            Reddit  North Carolina
# 3              Word of mouth (friends, family, etc)     California
# 4    Google search and news articles about foraging      California
# ..                                              ...             ...
# 145                                       Tinterweb             NaN
# 146            Word of mouth (friends, family, etc)              IL
# 147            Word of mouth (friends, family, etc)             NaN
# 148            Word of mouth (friends, family, etc)        Virginia
# 149                                          Reddit       Virginia
#
# [150 rows x 2 columns]

# %%
# filling NaaN values because those no bueno
new_df = new_df.fillna({
    'FindFF': 'Unknown',
    'State': 'Unknown'
    })
new_df
# Out:
#                                              FindFF           State
# 0              Word of mouth (friends, family, etc)         Florida
# 1                                            Google        New York
# 2                                            Reddit  North Carolina
# 3              Word of mouth (friends, family, etc)     California
# 4    Google search and news articles about foraging      California
# ..                                              ...             ...
# 145                                       Tinterweb         Unknown
# 146            Word of mouth (friends, family, etc)              IL
# 147            Word of mouth (friends, family, etc)         Unknown
# 148            Word of mouth (friends, family, etc)        Virginia
# 149                                          Reddit       Virginia
#
# [150 rows x 2 columns]

# %%
# copy df to save original data
testing_df = new_df.copy()
testing_df
# Out:
#                                              FindFF           State
# 0              Word of mouth (friends, family, etc)         Florida
# 1                                            Google        New York
# 2                                            Reddit  North Carolina
# 3              Word of mouth (friends, family, etc)     California
# 4    Google search and news articles about foraging      California
# ..                                              ...             ...
# 145                                       Tinterweb         Unknown
# 146            Word of mouth (friends, family, etc)              IL
# 147            Word of mouth (friends, family, etc)         Unknown
# 148            Word of mouth (friends, family, etc)        Virginia
# 149                                          Reddit       Virginia
#
# [150 rows x 2 columns]

# %%
# trimming capitalization

testing_df['FindFF'] = testing_df['FindFF'].str.strip().str.lower()   

testing_df['FindFF']
# Out:
# 0                word of mouth (friends, family, etc)
# 1                                              google
# 2                                              reddit
# 3                word of mouth (friends, family, etc)
# 4      google search and news articles about foraging
#                             ...
# 145                                         tinterweb
# 146              word of mouth (friends, family, etc)
# 147              word of mouth (friends, family, etc)
# 148              word of mouth (friends, family, etc)
# 149                                            reddit
# Name: FindFF, Length: 150, dtype: object

# %% [markdown]
# ## Cleaning 'How did you find out about Falling Fruit?'

# %%
# find unique answers
unique_categories = testing_df['FindFF'].unique()

print(unique_categories)
# Out:
# ['word of mouth (friends, family, etc)' 'google' 'reddit'
#  'google search and news articles about foraging' 'facebook' 'tiktok'
#  "don't remember" 'google search'
#  'i did an internet search years ago and got falling fruit as a result'
#  'i’ve been using it for so many years that i don’t even remember how i first heard about it'
#  'searching for a foraging tracking app'
#  'probably a search engine but a long time ago' "i can't remember"
#  'unknown' "i don't remember!" 'some sort of social media' 'internet'
#  'google search for foraging apps'
#  'i think google, i searched for an interactive map'
#  'i forget honestly, but it was somewhere on the internet'
#  'cannot remember' 'i think i did a google search'
#  'i was searching for an app that would do exactly as i was looking for to look for inventory of free fruits and vegetables around the area'
#  'internet search' 'instagram' "online, don't remember exactly"
#  'app store' "i don't remember, i've had the app a long time"
#  'googled fruit near me' 'appstore' 'found it online'
#  'just looking for foraging apps on app store'
#  'internet search for foraging maps' 'i forgot' 'twitter (x)'
#  'search engine' "can't remember" 'tumblr'
#  "i'm pretty sure i found it searching the internet for resources on pawpaw trees"
#  'not sure' 'search engine- doing research on foraging' 'web search'
#  'tumblr user.' "don't recall" 'from the podcast ologies'
#  'i think it was a news story many years ago' 'search (google)'
#  'i created it with ethan :)' 'searched for foraging applications.'
#  'i believe i heard about it on a robert evans podcast?'
#  'saw it in the google play store' 'cant remember but was online'
#  '"i wonder if" search' 'tinterweb']

# %%
for i, row in testing_df.iterrows():

    answer = testing_df.at[i,'FindFF']
    
    if isinstance(answer, str):
        
        if 'word of mouth' in answer:
            answer = 'word of mouth'
        
        elif any(keyword in answer for keyword in ['google', 'inter', 'search', 'online']):
            answer = 'internet search'
        
        elif any(keyword in answer for keyword in ['remember', "don't", 'not sure', 'social media', 'forgot']):
            answer = "don't remember"
        
        elif any(keyword in answer for keyword in ['app', 'store']):
            answer = 'app store'

        elif 'podcast' in answer:
            answer = 'podcast'

        # i did not realize tumblr was a good ad for FF
        elif 'tumblr' in answer:
            answer = 'tumblr'
        
        # grouping one of a kind answers while excluding NaN and former survey answers
        elif not any(keyword in answer for keyword in ['reddit', 'facebook', 'instagram', 'twitter (x)', 'unknown']):
            answer = 'unique'
    
    testing_df.at[i, 'FindFF'] = answer
    print(answer)
# Out:
# word of mouth
# internet search
# reddit
# word of mouth
# internet search
# word of mouth
# word of mouth
# facebook
# unique
# internet search
# don't remember
# internet search
# reddit
# internet search
# reddit
# internet search
# reddit
# don't remember
# facebook
# internet search
# internet search
# internet search
# reddit
# don't remember
# reddit
# unknown
# don't remember
# reddit
# word of mouth
# don't remember
# reddit
# word of mouth
# internet search
# reddit
# word of mouth
# internet search
# word of mouth
# internet search
# internet search
# word of mouth
# reddit
# word of mouth
# don't remember
# word of mouth
# word of mouth
# word of mouth
# don't remember
# internet search
# internet search
# reddit
# reddit
# word of mouth
# reddit
# don't remember
# facebook
# word of mouth
# don't remember
# word of mouth
# word of mouth
# facebook
# internet search
# reddit
# reddit
# reddit
# reddit
# reddit
# internet search
# instagram
# word of mouth
# word of mouth
# reddit
# word of mouth
# internet search
# app store
# don't remember
# reddit
# internet search
# app store
# word of mouth
# word of mouth
# internet search
# internet search
# app store
# word of mouth
# internet search
# word of mouth
# word of mouth
# internet search
# word of mouth
# internet search
# word of mouth
# internet search
# word of mouth
# reddit
# reddit
# don't remember
# word of mouth
# reddit
# don't remember
# twitter (x)
# reddit
# internet search
# word of mouth
# word of mouth
# don't remember
# don't remember
# facebook
# reddit
# tumblr
# word of mouth
# word of mouth
# internet search
# don't remember
# word of mouth
# internet search
# word of mouth
# reddit
# facebook
# word of mouth
# internet search
# word of mouth
# word of mouth
# internet search
# tumblr
# don't remember
# podcast
# unique
# word of mouth
# internet search
# reddit
# internet search
# unique
# reddit
# reddit
# word of mouth
# facebook
# internet search
# unknown
# podcast
# internet search
# word of mouth
# word of mouth
# word of mouth
# internet search
# internet search
# internet search
# word of mouth
# word of mouth
# word of mouth
# reddit

# %%
# double checking for unique responses
unique = testing_df['FindFF'].unique()
print(unique)
# Out:
# ['word of mouth' 'internet search' 'reddit' 'facebook' 'unique'
#  "don't remember" 'unknown' 'instagram' 'app store' 'twitter (x)' 'tumblr'
#  'podcast']

# %%
# can use this for data visualization
FindFF_counts = testing_df['FindFF'].value_counts()
FindFF_counts
# Out:
# FindFF
# word of mouth      46
# internet search    37
# reddit             30
# don't remember     16
# facebook            7
# unique              3
# app store           3
# unknown             2
# tumblr              2
# podcast             2
# instagram           1
# twitter (x)         1
# Name: count, dtype: int64

# %% [markdown]
# # Cleaning 'If you are located in the US, what state?'

# %%
# trimming capitalization

testing_df['State'] = testing_df['State'].str.strip().str.lower()   

testing_df['State']
# Out:
# 0             florida
# 1            new york
# 2      north carolina
# 3          california
# 4          california
#             ...
# 145           unknown
# 146                il
# 147           unknown
# 148          virginia
# 149          virginia
# Name: State, Length: 150, dtype: object

# %%
# setting up mapping abbreviations to proper state names
old_state_mapping = {
    "AL": "Alabama",
    "AK": "Alaska",
    "AZ": "Arizona",
    "AR": "Arkansas",
    "CA": "California",
    "CO": "Colorado",
    "CT": "Connecticut",
    "DE": "Delaware",
    "FL": "Florida",
    "GA": "Georgia",
    "HI": "Hawaii",
    "ID": "Idaho",
    "IL": "Illinois",
    "IN": "Indiana",
    "IA": "Iowa",
    "KS": "Kansas",
    "KY": "Kentucky",
    "LA": "Louisiana",
    "ME": "Maine",
    "MD": "Maryland",
    "MA": "Massachusetts",
    "MI": "Michigan",
    "MN": "Minnesota",
    "MS": "Mississippi",
    "MO": "Missouri",
    "MT": "Montana",
    "NE": "Nebraska",
    "NV": "Nevada",
    "NH": "New Hampshire",
    "NJ": "New Jersey",
    "NM": "New Mexico",
    "NY": "New York",
    "NC": "North Carolina",
    "ND": "North Dakota",
    "OH": "Ohio",
    "OK": "Oklahoma",
    "OR": "Oregon",
    "PA": "Pennsylvania",
    "RI": "Rhode Island",
    "SC": "South Carolina",
    "SD": "South Dakota",
    "TN": "Tennessee",
    "TX": "Texas",
    "UT": "Utah",
    "VT": "Vermont",
    "VA": "Virginia",
    "WA": "Washington",
    "WV": "West Virginia",
    "WI": "Wisconsin",
    "WY": "Wyoming",
    "DC": "District of Columbia",
    "AS": "American Samoa",
    "GU": "Guam",
    "MP": "Northern Mariana Islands",
    "PR": "Puerto Rico",
    "UM": "United States Minor Outlying Islands",
    "VI": "Virgin Islands, U.S."
}

# %%
# accepted US States ONLY!!! also ensuring values in old_state_mapping are same in states list
us_states_list = list(old_state_mapping.values())
us_states_list
# Out:
# ['Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming',
#  'District of Columbia',
#  'American Samoa',
#  'Guam',
#  'Northern Mariana Islands',
#  'Puerto Rico',
#  'United States Minor Outlying Islands',
#  'Virgin Islands, U.S.']

# %%
# lower casing states list 
for index, item in enumerate(us_states_list):
    us_states_list[index] = item.lower()

us_states_list
# Out:
# ['alabama',
#  'alaska',
#  'arizona',
#  'arkansas',
#  'california',
#  'colorado',
#  'connecticut',
#  'delaware',
#  'florida',
#  'georgia',
#  'hawaii',
#  'idaho',
#  'illinois',
#  'indiana',
#  'iowa',
#  'kansas',
#  'kentucky',
#  'louisiana',
#  'maine',
#  'maryland',
#  'massachusetts',
#  'michigan',
#  'minnesota',
#  'mississippi',
#  'missouri',
#  'montana',
#  'nebraska',
#  'nevada',
#  'new hampshire',
#  'new jersey',
#  'new mexico',
#  'new york',
#  'north carolina',
#  'north dakota',
#  'ohio',
#  'oklahoma',
#  'oregon',
#  'pennsylvania',
#  'rhode island',
#  'south carolina',
#  'south dakota',
#  'tennessee',
#  'texas',
#  'utah',
#  'vermont',
#  'virginia',
#  'washington',
#  'west virginia',
#  'wisconsin',
#  'wyoming',
#  'district of columbia',
#  'american samoa',
#  'guam',
#  'northern mariana islands',
#  'puerto rico',
#  'united states minor outlying islands',
#  'virgin islands, u.s.']

# %%
# lower casing abbreviation mapping dictionary
state_mapping = {
    k.lower(): v.lower() for k, v in old_state_mapping.items()
}

state_mapping
# Out:
# {'al': 'alabama',
#  'ak': 'alaska',
#  'az': 'arizona',
#  'ar': 'arkansas',
#  'ca': 'california',
#  'co': 'colorado',
#  'ct': 'connecticut',
#  'de': 'delaware',
#  'fl': 'florida',
#  'ga': 'georgia',
#  'hi': 'hawaii',
#  'id': 'idaho',
#  'il': 'illinois',
#  'in': 'indiana',
#  'ia': 'iowa',
#  'ks': 'kansas',
#  'ky': 'kentucky',
#  'la': 'louisiana',
#  'me': 'maine',
#  'md': 'maryland',
#  'ma': 'massachusetts',
#  'mi': 'michigan',
#  'mn': 'minnesota',
#  'ms': 'mississippi',
#  'mo': 'missouri',
#  'mt': 'montana',
#  'ne': 'nebraska',
#  'nv': 'nevada',
#  'nh': 'new hampshire',
#  'nj': 'new jersey',
#  'nm': 'new mexico',
#  'ny': 'new york',
#  'nc': 'north carolina',
#  'nd': 'north dakota',
#  'oh': 'ohio',
#  'ok': 'oklahoma',
#  'or': 'oregon',
#  'pa': 'pennsylvania',
#  'ri': 'rhode island',
#  'sc': 'south carolina',
#  'sd': 'south dakota',
#  'tn': 'tennessee',
#  'tx': 'texas',
#  'ut': 'utah',
#  'vt': 'vermont',
#  'va': 'virginia',
#  'wa': 'washington',
#  'wv': 'west virginia',
#  'wi': 'wisconsin',
#  'wy': 'wyoming',
#  'dc': 'district of columbia',
#  'as': 'american samoa',
#  'gu': 'guam',
#  'mp': 'northern mariana islands',
#  'pr': 'puerto rico',
#  'um': 'united states minor outlying islands',
#  'vi': 'virgin islands, u.s.'}

# %%
# find unique answers
unique_states = testing_df['State'].unique()

print(unique_states)
# Out:
# ['florida' 'new york' 'north carolina' 'california' 'or' 'oklahoma'
#  'michigan' 'unknown' 'west virginia' 'iowa' 'maryland' 'delaware'
#  'washington' 'va' 'massachusetts' 'oregon'
#  'currently virginia, but florida and alabama before that' 'ut' 'virginia'
#  'md' 'ohio' 'tn' 'tennessee' 'connecticut' 'ca' 'colorado' 'arizona'
#  'illinois' 'wisconsin' 'missouri' 'western australia' 'new jersey'
#  'north carolina, previously in boston massachusetts' 'pennsylvania'
#  'mass' 'pa' 'co' 'utah' 'louisiana' 'adirondacks, ny' 'pacific nw'
#  'indiana' 'wa' 'district of columbia' 'minnesota' 'south carolina' 'fl'
#  'il']

# %%
# this is assuming everyone spelled correctly!!!!!
for i, row in testing_df.iterrows():

    answer = testing_df.at[i,'State']

    if isinstance(answer, str):
        # replace abbreviations with full state name
        for key, value in state_mapping:

            if key == answer:
                answer = value

        # handling special cases
        if answer == 'unknown':
            answer = answer

        elif 'currently virginia' in answer:
            answer = 'virginia'

        elif 'north carolina, previously in boston massachusetts' in answer:
            answer = 'north carolina'

        elif 'adirondacks, ny' in answer:
            answer = 'new york'

        elif 'mass' in answer:
            answer = 'massachusetts'
        
        elif answer not in us_states_list:
            answer = 'not in US'
    
    testing_df.at[i, 'State'] = answer
    print(answer)
# Out:
# florida
# new york
# north carolina
# california
# california
# not in US
# california
# oklahoma
# michigan
# unknown
# west virginia
# new york
# iowa
# iowa
# maryland
# delaware
# washington
# not in US
# massachusetts
# oregon
# california
# virginia
# not in US
# unknown
# virginia
# not in US
# california
# unknown
# ohio
# virginia
# maryland
# not in US
# maryland
# tennessee
# california
# connecticut
# not in US
# unknown
# new york
# virginia
# california
# colorado
# arizona
# california
# unknown
# washington
# california
# maryland
# not in US
# michigan
# illinois
# unknown
# wisconsin
# massachusetts
# missouri
# colorado
# unknown
# unknown
# unknown
# unknown
# not in US
# unknown
# maryland
# not in US
# california
# arizona
# washington
# new jersey
# illinois
# california
# north carolina
# california
# pennsylvania
# california
# oklahoma
# north carolina
# unknown
# north carolina
# unknown
# unknown
# massachusetts
# unknown
# unknown
# pennsylvania
# virginia
# not in US
# illinois
# not in US
# oregon
# unknown
# utah
# unknown
# louisiana
# new york
# oregon
# new york
# michigan
# colorado
# not in US
# california
# indiana
# unknown
# not in US
# california
# district of columbia
# illinois
# maryland
# maryland
# minnesota
# washington
# unknown
# tennessee
# unknown
# south carolina
# not in US
# new york
# michigan
# louisiana
# indiana
# unknown
# maryland
# unknown
# not in US
# unknown
# ohio
# washington
# maryland
# colorado
# utah
# unknown
# new york
# oregon
# unknown
# california
# unknown
# michigan
# unknown
# illinois
# ohio
# california
# colorado
# utah
# ohio
# unknown
# unknown
# unknown
# not in US
# unknown
# virginia
# virginia

# %%
# checking for unique answers again
testing_df['State'].unique()
# Out:
# array(['florida', 'new york', 'north carolina', 'california', 'not in US',
#        'oklahoma', 'michigan', 'unknown', 'west virginia', 'iowa',
#        'maryland', 'delaware', 'washington', 'massachusetts', 'oregon',
#        'virginia', 'ohio', 'tennessee', 'connecticut', 'colorado',
#        'arizona', 'illinois', 'wisconsin', 'missouri', 'new jersey',
#        'pennsylvania', 'utah', 'louisiana', 'indiana',
#        'district of columbia', 'minnesota', 'south carolina'],
#       dtype=object)

# %%
# checking proportion of answers
state_counts = testing_df['State'].value_counts()
state_counts
# Out:
# State
# unknown                 32
# california              17
# not in US               16
# maryland                 9
# new york                 7
# virginia                 7
# washington               5
# illinois                 5
# colorado                 5
# michigan                 5
# oregon                   4
# ohio                     4
# north carolina           4
# massachusetts            3
# utah                     3
# pennsylvania             2
# iowa                     2
# tennessee                2
# indiana                  2
# oklahoma                 2
# arizona                  2
# louisiana                2
# district of columbia     1
# minnesota                1
# florida                  1
# new jersey               1
# missouri                 1
# wisconsin                1
# connecticut              1
# delaware                 1
# west virginia            1
# south carolina           1
# Name: count, dtype: int64

# %%
# double-checking if there really are 32 unknowns 
unknown_indices = testing_df[testing_df['State'] == 'unknown'].index

print(unknown_indices)
# Out:
# Index([  9,  23,  27,  37,  44,  51,  56,  57,  58,  59,  61,  76,  78,  79,
#         81,  82,  89,  91, 101, 110, 112, 119, 121, 123, 129, 132, 134, 136,
#        143, 144, 145, 147],
#       dtype='int64')

# %%
rows = [9,  23,  27,  37,  44,  51,  56,  57,  58,  59,  61,  76,  78,  79,
        81,  82,  89,  91, 101, 110, 112, 119, 121, 123, 129, 132, 134, 136,
       143, 144, 145, 147]

testing_df.iloc[rows]
# Out:
#               FindFF    State
# 9    internet search  unknown
# 23    don't remember  unknown
# 27            reddit  unknown
# 37   internet search  unknown
# 44     word of mouth  unknown
# 51     word of mouth  unknown
# 56    don't remember  unknown
# 57     word of mouth  unknown
# 58     word of mouth  unknown
# 59          facebook  unknown
# 61            reddit  unknown
# 76   internet search  unknown
# 78     word of mouth  unknown
# 79     word of mouth  unknown
# 81   internet search  unknown
# 82         app store  unknown
# 89   internet search  unknown
# 91   internet search  unknown
# 101  internet search  unknown
# 110    word of mouth  unknown
# 112   don't remember  unknown
# 119  internet search  unknown
# 121    word of mouth  unknown
# 123           tumblr  unknown
# 129           reddit  unknown
# 132           reddit  unknown
# 134    word of mouth  unknown
# 136  internet search  unknown
# 143  internet search  unknown
# 144  internet search  unknown
# 145  internet search  unknown
# 147    word of mouth  unknown

# %%
testing_df
# Out:
#               FindFF           State
# 0      word of mouth         florida
# 1    internet search        new york
# 2             reddit  north carolina
# 3      word of mouth      california
# 4    internet search      california
# ..               ...             ...
# 145  internet search         unknown
# 146    word of mouth       not in US
# 147    word of mouth         unknown
# 148    word of mouth        virginia
# 149           reddit        virginia
#
# [150 rows x 2 columns]

# %%
testing_df.to_csv("findFF_states_cleaned.csv", index=False)
